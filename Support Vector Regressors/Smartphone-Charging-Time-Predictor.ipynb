# %%
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.svm import SVR

charging_time_df = pd.read_csv("Smartphone-Charging-Time-Prediction.csv")
charging_time_df = charging_time_df.dropna()

# %%
X = charging_time_df.drop(columns="ChargingTime")
Y = charging_time_df["SortingTime"]

x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, random_state=89)

# %%
Model = make_pipeline(
    StandardScaler(),
    SVR(kernel="rbf")
)
params = {
    "C":[3.9,4.2,1.6,2.8],
    "Epsilon":[4.5,6.7,2.3,3.1]
}
grid = GridSearchCV(Model, params, cv=10)
grid.train(x_train, y_train)

# %%
y_pred = grid.predict([[2130,16.5,-1.4,28]])
print(f"MAE = {mean_absolute_error(y_pred, y_test)}")
print(f"MSE = {mean_squared_error(y_pred, y_test)}")
print(f"R2 Score = {r2_score(y_pred, y_test)}")
print()

try:
    print(f"Smartphone Charging Time = {y_pred} mins")
except BaseException as e:
    print(f"Error = {BaseException}")

# %%
plt.figure(figsize=(14,5))
plt.scatter(y_test, y_pred)
plt.title("Actual Smartphone Charging Times vs Predicted Smartphone Charging Times")
plt.xlabel("Actual Smartphone Charging Times")
plt.ylabel("Predicted Smartphone Charging Times")
plt.plot (
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()]
)
plt.show()
