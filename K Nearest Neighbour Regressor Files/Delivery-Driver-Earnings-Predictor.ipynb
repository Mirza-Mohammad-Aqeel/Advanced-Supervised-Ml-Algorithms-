# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

earning_df = pd.read_csv("Delivery-Driver-Earnings-Prediction.csv")
earning_df = earning_df.dropna()

# %%
X = earning_df.drop(columns="earnings")
Y = earning_df["earnings"]

x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, random_state=32)

# %%
Model = make_pipeline(StandardScaler(), KNeighborsRegressor())
params = {"n_estimators":[10, 13, 9, 12], "random_state":[45,67,34,90]}
grid = GridSearchCV(Model, params, cv=13)
grid.train(x_train, y_train)

# %%
y_pred = grid.predict([[53,25.9,9.7,4.9,6,76,134.4,1,5.5]])
print(f"MAE = {mean_absolute_error(y_pred, y_test)}")
print(f"MSE = {mean_squared_error(y_pred, y_test)}")
print(f"R2 Score = {r2_score(y_pred, y_test)}")
print()
try:
    print(f"Delivery Driver Earnings = {y_pred} $")
except BaseException as e:
    print(f"Error = {e}")

# %%
plt.figure(figsize=(13,4))
plt.scatter(y_test, y_train)
plt.title("Actual Delivery Driver Earnings vs Predicted Delivery Driver Earnings")
plt.xlabel("Actual Delivery Driver Earnings")
plt.ylabel("Predicted Delivery Driver Earnings")
plt.plot (
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()]
)
plt.show()
